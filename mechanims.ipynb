# %% [markdown]
# # Laplace Example

# %%
# Import libs
import math
from scipy.stats import laplace

"""
-------------
| Dataset X |
--------------------------
| # User       # Has HIV |
--------------------------
| # Andrew     False     |
| # Bob        True      |
| # Carly      True      |
| # Dean       True      |
| # Ernest     False     |
| # Florence   False     |
--------------------------

Assume the function F as a count query, where:

F = number of individuals which hold HIV

Then, F(X) = 3.

Now, the neighbouring Dataset Y can be generated either from:
    1. Dataset X added in another user such {Gary:False} or {Harry:True}
    2. Dataset X removed in one existing user such {Andrew:False} or {Bob:True}
    3. Dataset X modified in one existing user such {Andrew:False} to {Andrew:True} or {Andrew:False} to {Andy:False}

Thus, F(Y) can assume values 2, 3 or 4 depending on Y's generation pattern.
"""

# Response of function F applied to dataset X
fx = 3

# Responses of function F applied to the possible datasets Y
fy = [2, 3, 4]

# Sensitivity of a count query (always equals to one)
delta_s = 1

# Standard epsilon values in order of magnitude -- lower to higher
eps = [0.01, 0.1, 0.5, 1.0, 2.0, 3.0]

# Mean of the Laplace distribution (always equals to zero)
laplace_mean = 0.0

print("Sensitivity = {}".format(delta_s))

for i_fy in fy:
    print("\nF(X) = {}\nF(Y) = {}".format(fx, i_fy))
    
    for j_eps in eps:
        # Sampling noise from the Laplace distribution with zero mean and (sensitivity/epsilon) scale
        noise = laplace.rvs(loc=laplace_mean, scale=delta_s/j_eps, size=1)[0]
        
        # Generate one possible z output from the sum of fx + noise
        z = fx + noise
        
        # Calculate the probability of occurrence of the output z in datasets X and Y, respectively
        fx_prob = laplace.pdf(x=z, loc=fx, scale=delta_s/j_eps)
        fy_prob = laplace.pdf(x=z, loc=i_fy, scale=delta_s/j_eps)
        
        print("\n\tEpsilon = {}\n".format(j_eps))
        
        print("\t\tNoise = {}\n\t\tz (F(X) + noise) = {}\n".format(round(noise, 2), round(z, 2)))
        
        print("\t\tProb(Fx(z)) = {} %\n\t\tProb(Fy(z)) = {} %".format(round(fx_prob, 5), round(fy_prob, 5)))
        print("\t\tProb(Fx(z)) / Prob(Fy(z)) = {}\n".format(round((fx_prob/fy_prob), 5)))
        
        print("\t\tExp(epsilon) = {}\n\t\tExp(-epsilon) = {}\n".format(round(math.exp(j_eps), 5), round(math.exp(-j_eps), 5)))
        
        print("\t\tProb(Fx(z)) / Prob(Fy(z)) <= Exp(epsilon) ?")
        print("\t\t{} <= {} ?\n\t\t{}\n".format(round((fx_prob/fy_prob), 5), round(math.exp(j_eps), 5), (round((fx_prob/fy_prob), 5) <= round(math.exp(j_eps), 5))))
        
        print("\t\tProb(Fx(z)) / Prob(Fy(z)) >= Exp(-epsilon) ?")
        print("\t\t{} >= {} ?\n\t\t{}".format(round((fx_prob/fy_prob), 5), round(math.exp(-j_eps), 5), (round((fx_prob/fy_prob), 5) >= round(math.exp(-j_eps), 5))))
# Out:
# Sensitivity = 1
#
# F(X) = 3
# F(Y) = 2
#
# 	Epsilon = 0.01
#
# 		Noise = 20.0
# 		z (F(X) + noise) = 23.0
#
# 		Prob(Fx(z)) = 0.00409 %
# 		Prob(Fy(z)) = 0.00405 %
# 		Prob(Fx(z)) / Prob(Fy(z)) = 1.01005
#
# 		Exp(epsilon) = 1.01005
# 		Exp(-epsilon) = 0.99005
#
# 		Prob(Fx(z)) / Prob(Fy(z)) <= Exp(epsilon) ?
# 		1.01005 <= 1.01005 ?
# 		True
#
# 		Prob(Fx(z)) / Prob(Fy(z)) >= Exp(-epsilon) ?
# 		1.01005 >= 0.99005 ?
# 		True
#
# 	Epsilon = 0.1
#
# 		Noise = -3.52
# 		z (F(X) + noise) = -0.52
#
# 		Prob(Fx(z)) = 0.03517 %
# 		Prob(Fy(z)) = 0.03887 %
# 		Prob(Fx(z)) / Prob(Fy(z)) = 0.90484
#
# 		Exp(epsilon) = 1.10517
# 		Exp(-epsilon) = 0.90484
#
# 		Prob(Fx(z)) / Prob(Fy(z)) <= Exp(epsilon) ?
# 		0.90484 <= 1.10517 ?
# 		True
#
# 		Prob(Fx(z)) / Prob(Fy(z)) >= Exp(-epsilon) ?
# 		0.90484 >= 0.90484 ?
# 		True
#
# 	Epsilon = 0.5
#
# 		Noise = -0.62
# 		z (F(X) + noise) = 2.38
#
# 		Prob(Fx(z)) = 0.18326 %
# 		Prob(Fy(z)) = 0.20685 %
# 		Prob(Fx(z)) / Prob(Fy(z)) = 0.88595
#
# 		Exp(epsilon) = 1.64872
# 		Exp(-epsilon) = 0.60653
#
# 		Prob(Fx(z)) / Prob(Fy(z)) <= Exp(epsilon) ?
# 		0.88595 <= 1.64872 ?
# 		True
#
# 		Prob(Fx(z)) / Prob(Fy(z)) >= Exp(-epsilon) ?
# 		0.88595 >= 0.60653 ?
# 		True
#
# 	Epsilon = 1.0
#
# 		Noise = 1.75
# 		z (F(X) + noise) = 4.75
#
# 		Prob(Fx(z)) = 0.08694 %
# 		Prob(Fy(z)) = 0.03199 %
# 		Prob(Fx(z)) / Prob(Fy(z)) = 2.71828
#
# 		Exp(epsilon) = 2.71828
# 		Exp(-epsilon) = 0.36788
#
# 		Prob(Fx(z)) / Prob(Fy(z)) <= Exp(epsilon) ?
# 		2.71828 <= 2.71828 ?
# 		True
#
# 		Prob(Fx(z)) / Prob(Fy(z)) >= Exp(-epsilon) ?
# 		2.71828 >= 0.36788 ?
# 		True
#
# 	Epsilon = 2.0
#
# 		Noise = 0.25
# 		z (F(X) + noise) = 3.25
#
# 		Prob(Fx(z)) = 0.60844 %
# 		Prob(Fy(z)) = 0.08234 %
# 		Prob(Fx(z)) / Prob(Fy(z)) = 7.38906
#
# 		Exp(epsilon) = 7.38906
# 		Exp(-epsilon) = 0.13534
#
# 		Prob(Fx(z)) / Prob(Fy(z)) <= Exp(epsilon) ?
# 		7.38906 <= 7.38906 ?
# 		True
#
# 		Prob(Fx(z)) / Prob(Fy(z)) >= Exp(-epsilon) ?
# 		7.38906 >= 0.13534 ?
# 		True
#
# 	Epsilon = 3.0
#
# 		Noise = -0.24
# 		z (F(X) + noise) = 2.76
#
# 		Prob(Fx(z)) = 0.72737 %
# 		Prob(Fy(z)) = 0.15401 %
# 		Prob(Fx(z)) / Prob(Fy(z)) = 4.72295
#
# 		Exp(epsilon) = 20.08554
# 		Exp(-epsilon) = 0.04979
#
# 		Prob(Fx(z)) / Prob(Fy(z)) <= Exp(epsilon) ?
# 		4.72295 <= 20.08554 ?
# 		True
#
# 		Prob(Fx(z)) / Prob(Fy(z)) >= Exp(-epsilon) ?
# 		4.72295 >= 0.04979 ?
# 		True
#
# F(X) = 3
# F(Y) = 3
#
# 	Epsilon = 0.01
#
# 		Noise = 226.69
# 		z (F(X) + noise) = 229.69
#
# 		Prob(Fx(z)) = 0.00052 %
# 		Prob(Fy(z)) = 0.00052 %
# 		Prob(Fx(z)) / Prob(Fy(z)) = 1.0
#
# 		Exp(epsilon) = 1.01005
# 		Exp(-epsilon) = 0.99005
#
# 		Prob(Fx(z)) / Prob(Fy(z)) <= Exp(epsilon) ?
# 		1.0 <= 1.01005 ?
# 		True
#
# 		Prob(Fx(z)) / Prob(Fy(z)) >= Exp(-epsilon) ?
# 		1.0 >= 0.99005 ?
# 		True
#
# 	Epsilon = 0.1
#
# 		Noise = -9.09
# 		z (F(X) + noise) = -6.09
#
# 		Prob(Fx(z)) = 0.02014 %
# 		Prob(Fy(z)) = 0.02014 %
# 		Prob(Fx(z)) / Prob(Fy(z)) = 1.0
#
# 		Exp(epsilon) = 1.10517
# 		Exp(-epsilon) = 0.90484
#
# 		Prob(Fx(z)) / Prob(Fy(z)) <= Exp(epsilon) ?
# 		1.0 <= 1.10517 ?
# 		True
#
# 		Prob(Fx(z)) / Prob(Fy(z)) >= Exp(-epsilon) ?
# 		1.0 >= 0.90484 ?
# 		True
#
# 	Epsilon = 0.5
#
# 		Noise = -1.93
# 		z (F(X) + noise) = 1.07
#
# 		Prob(Fx(z)) = 0.09505 %
# 		Prob(Fy(z)) = 0.09505 %
# 		Prob(Fx(z)) / Prob(Fy(z)) = 1.0
#
# 		Exp(epsilon) = 1.64872
# 		Exp(-epsilon) = 0.60653
#
# 		Prob(Fx(z)) / Prob(Fy(z)) <= Exp(epsilon) ?
# 		1.0 <= 1.64872 ?
# 		True
#
# 		Prob(Fx(z)) / Prob(Fy(z)) >= Exp(-epsilon) ?
# 		1.0 >= 0.60653 ?
# 		True
#
# 	Epsilon = 1.0
#
# 		Noise = -0.03
# 		z (F(X) + noise) = 2.97
#
# 		Prob(Fx(z)) = 0.48548 %
# 		Prob(Fy(z)) = 0.48548 %
# 		Prob(Fx(z)) / Prob(Fy(z)) = 1.0
#
# 		Exp(epsilon) = 2.71828
# 		Exp(-epsilon) = 0.36788
#
# 		Prob(Fx(z)) / Prob(Fy(z)) <= Exp(epsilon) ?
# 		1.0 <= 2.71828 ?
# 		True
#
# 		Prob(Fx(z)) / Prob(Fy(z)) >= Exp(-epsilon) ?
# 		1.0 >= 0.36788 ?
# 		True
#
# 	Epsilon = 2.0
#
# 		Noise = 0.24
# 		z (F(X) + noise) = 3.24
#
# 		Prob(Fx(z)) = 0.62326 %
# 		Prob(Fy(z)) = 0.62326 %
# 		Prob(Fx(z)) / Prob(Fy(z)) = 1.0
#
# 		Exp(epsilon) = 7.38906
# 		Exp(-epsilon) = 0.13534
#
# 		Prob(Fx(z)) / Prob(Fy(z)) <= Exp(epsilon) ?
# 		1.0 <= 7.38906 ?
# 		True
#
# 		Prob(Fx(z)) / Prob(Fy(z)) >= Exp(-epsilon) ?
# 		1.0 >= 0.13534 ?
# 		True
#
# 	Epsilon = 3.0
#
# 		Noise = 0.24
# 		z (F(X) + noise) = 3.24
#
# 		Prob(Fx(z)) = 0.74101 %
# 		Prob(Fy(z)) = 0.74101 %
# 		Prob(Fx(z)) / Prob(Fy(z)) = 1.0
#
# 		Exp(epsilon) = 20.08554
# 		Exp(-epsilon) = 0.04979
#
# 		Prob(Fx(z)) / Prob(Fy(z)) <= Exp(epsilon) ?
# 		1.0 <= 20.08554 ?
# 		True
#
# 		Prob(Fx(z)) / Prob(Fy(z)) >= Exp(-epsilon) ?
# 		1.0 >= 0.04979 ?
# 		True
#
# F(X) = 3
# F(Y) = 4
#
# 	Epsilon = 0.01
#
# 		Noise = -106.77
# 		z (F(X) + noise) = -103.77
#
# 		Prob(Fx(z)) = 0.00172 %
# 		Prob(Fy(z)) = 0.0017 %
# 		Prob(Fx(z)) / Prob(Fy(z)) = 1.01005
#
# 		Exp(epsilon) = 1.01005
# 		Exp(-epsilon) = 0.99005
#
# 		Prob(Fx(z)) / Prob(Fy(z)) <= Exp(epsilon) ?
# 		1.01005 <= 1.01005 ?
# 		True
#
# 		Prob(Fx(z)) / Prob(Fy(z)) >= Exp(-epsilon) ?
# 		1.01005 >= 0.99005 ?
# 		True
#
# 	Epsilon = 0.1
#
# 		Noise = 0.31
# 		z (F(X) + noise) = 3.31
#
# 		Prob(Fx(z)) = 0.04846 %
# 		Prob(Fy(z)) = 0.04668 %
# 		Prob(Fx(z)) / Prob(Fy(z)) = 1.03819
#
# 		Exp(epsilon) = 1.10517
# 		Exp(-epsilon) = 0.90484
#
# 		Prob(Fx(z)) / Prob(Fy(z)) <= Exp(epsilon) ?
# 		1.03819 <= 1.10517 ?
# 		True
#
# 		Prob(Fx(z)) / Prob(Fy(z)) >= Exp(-epsilon) ?
# 		1.03819 >= 0.90484 ?
# 		True
#
# 	Epsilon = 0.5
#
# 		Noise = 0.6
# 		z (F(X) + noise) = 3.6
#
# 		Prob(Fx(z)) = 0.18505 %
# 		Prob(Fy(z)) = 0.20485 %
# 		Prob(Fx(z)) / Prob(Fy(z)) = 0.90333
#
# 		Exp(epsilon) = 1.64872
# 		Exp(-epsilon) = 0.60653
#
# 		Prob(Fx(z)) / Prob(Fy(z)) <= Exp(epsilon) ?
# 		0.90333 <= 1.64872 ?
# 		True
#
# 		Prob(Fx(z)) / Prob(Fy(z)) >= Exp(-epsilon) ?
# 		0.90333 >= 0.60653 ?
# 		True
#
# 	Epsilon = 1.0
#
# 		Noise = 1.78
# 		z (F(X) + noise) = 4.78
#
# 		Prob(Fx(z)) = 0.08423 %
# 		Prob(Fy(z)) = 0.22897 %
# 		Prob(Fx(z)) / Prob(Fy(z)) = 0.36788
#
# 		Exp(epsilon) = 2.71828
# 		Exp(-epsilon) = 0.36788
#
# 		Prob(Fx(z)) / Prob(Fy(z)) <= Exp(epsilon) ?
# 		0.36788 <= 2.71828 ?
# 		True
#
# 		Prob(Fx(z)) / Prob(Fy(z)) >= Exp(-epsilon) ?
# 		0.36788 >= 0.36788 ?
# 		True
#
# 	Epsilon = 2.0
#
# 		Noise = -0.08
# 		z (F(X) + noise) = 2.92
#
# 		Prob(Fx(z)) = 0.8581 %
# 		Prob(Fy(z)) = 0.11613 %
# 		Prob(Fx(z)) / Prob(Fy(z)) = 7.38906
#
# 		Exp(epsilon) = 7.38906
# 		Exp(-epsilon) = 0.13534
#
# 		Prob(Fx(z)) / Prob(Fy(z)) <= Exp(epsilon) ?
# 		7.38906 <= 7.38906 ?
# 		True
#
# 		Prob(Fx(z)) / Prob(Fy(z)) >= Exp(-epsilon) ?
# 		7.38906 >= 0.13534 ?
# 		True
#
# 	Epsilon = 3.0
#
# 		Noise = 0.05
# 		z (F(X) + noise) = 3.05
#
# 		Prob(Fx(z)) = 1.27828 %
# 		Prob(Fy(z)) = 0.08763 %
# 		Prob(Fx(z)) / Prob(Fy(z)) = 14.58647
#
# 		Exp(epsilon) = 20.08554
# 		Exp(-epsilon) = 0.04979
#
# 		Prob(Fx(z)) / Prob(Fy(z)) <= Exp(epsilon) ?
# 		14.58647 <= 20.08554 ?
# 		True
#
# 		Prob(Fx(z)) / Prob(Fy(z)) >= Exp(-epsilon) ?
# 		14.58647 >= 0.04979 ?
# 		True
